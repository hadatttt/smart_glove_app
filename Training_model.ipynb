# %%
# === 1. Mount Google Drive ===
from google.colab import drive
drive.mount('/content/drive')

# === 2. Cài đặt thư viện (nếu cần) ===
# !pip install scikit-learn joblib pandas

# === 3. Đọc dữ liệu từ file CSV trên Google Drive ===
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
import joblib

# Đường dẫn file trên Google Drive
file_path = "/content/drive/MyDrive/ML/pbl5/dulieu.csv"
df = pd.read_csv(file_path)

# Ép kiểu cột Label sang chuỗi để tránh lỗi khi in classification_report
df["Label"] = df["Label"].astype(str)

# Tách đặc trưng và nhãn
X = df.drop(columns=["Label"])
y = df["Label"]

# Chuẩn hoá dữ liệu
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Mã hoá nhãn
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Chia dữ liệu train/test
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded
)

# === 5. Huấn luyện mô hình ===
clf = RandomForestClassifier(n_estimators=200, random_state=42)
clf.fit(X_train, y_train)

# === 6. Đánh giá mô hình ===
y_pred = clf.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print(f"✅ Accuracy: {acc:.4f}\n")
print("📋 Classification Report:\n")
print(classification_report(y_test, y_pred, target_names=le.classes_))

# === 7. Lưu mô hình và các đối tượng cần thiết ===
joblib.dump(clf, "glove_model.pkl")
joblib.dump(scaler, "glove_scaler.pkl")
joblib.dump(le, "glove_label_encoder.pkl")
print("💾 Saved model, scaler, and label encoder.")

# === 8. Tải xuống mô hình về máy (nếu cần) ===
from google.colab import files
files.download("glove_model.pkl")
files.download("glove_scaler.pkl")
files.download("glove_label_encoder.pkl")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...
# ✅ Accuracy: 0.9963
#
# 📋 Classification Report:
#
#               precision    recall  f1-score   support
#
#            A       1.00      1.00      1.00        23
#            B       1.00      1.00      1.00        22
#            D       1.00      1.00      1.00        18
#            E       1.00      1.00      1.00        20
#            F       1.00      1.00      1.00        13
#            G       1.00      1.00      1.00        25
#            H       1.00      1.00      1.00        22
#            I       1.00      1.00      1.00        18
#            J       1.00      1.00      1.00        18
#            K       0.71      1.00      0.83         5
#            L       1.00      1.00      1.00        24
#            M       1.00      1.00      1.00        20
#            N       1.00      1.00      1.00        19
# ...
